# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("householdtask3.csv")
data
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
df=pd.DataFrame(data)

df.columns
# Out:
# Index(['year', 'tot_hhs', 'own', 'own_wm', 'own_prop', 'own_wm_prop',
#        'prop_hhs', 'age', 'size', 'income', 'expenditure', 'eqv_income',
#        'eqv_exp'],
#       dtype='object')

# %%
plt.scatter(df['year'],df['tot_hhs'],color="red",label="household")
plt.title (" Scatter Plot")

plt.xlabel ( 'year')
plt.ylabel('total house' )
plt.colorbar ()
plt.show ()

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['year'], df['tot_hhs'], color='blue', label='household')
plt.xlabel('year')
plt.ylabel('tot_hhs')
plt.title('yearly house')
plt.legend()
plt.show()

# %%
# Creating a line chart for 'income' and 'expenditure'
plt.figure(figsize=(8,4))
plt.plot(df['year'], df['income'], marker='o', linestyle='-', color='green', label='Income')
plt.plot(df['year'], df['expenditure'], marker='x', linestyle='--', color='red', label='Expenditure')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Income vs Expenditure Over the Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
identifier_column = 'year'  

for column in df.columns:
    if column != identifier_column:
        plt.figure(figsize=(10, 6))
        plt.plot(df[identifier_column], df[column], marker='o', label=column)
        plt.xlabel(identifier_column)
        plt.ylabel(column)
        plt.title(f'Line Chart for {column}')
        plt.legend()
        plt.show()

# %%
identifier_column = 'year'

for column in data.columns:
    if column != identifier_column:
        plt.figure(figsize=(10, 6))
        plt.bar(data[identifier_column], data[column], label=column)
        plt.xlabel(identifier_column)
        plt.ylabel(column)
        plt.title(f'Bar Chart for {column}')
        plt.legend()
        plt.show()
